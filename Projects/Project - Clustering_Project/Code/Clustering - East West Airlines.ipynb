# %% [markdown]
# # AIRLINES ANALYSIS

# %%
# importing the packages--
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
# reading the data file--
def read_data():
    data=pd.read_excel(r"D:\Master in Data Science\Python\Projects\Clustering_Project_10/eEastWestAirlines.xlsx")
    return data

# %%
# calling the function--
data= read_data()
print(data.head(2))
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0

# %%
# copying the data--
data.copy()
data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
# data analysis--
data.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
data.describe()
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %%
# checking the missing values--
data.isnull().sum()
# Out:
# ID#                  0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
data.shape
# Out:
# (3999, 12)

# %%
data.corr()
# Out:
#                         ID#   Balance  Qual_miles  cc1_miles  cc2_miles  \
# ID#                1.000000 -0.243737   -0.019374  -0.224465   0.020291
# Balance           -0.243737  1.000000    0.108722   0.338344  -0.008804
# Qual_miles        -0.019374  0.108722    1.000000   0.007931  -0.013923
# cc1_miles         -0.224465  0.338344    0.007931   1.000000  -0.068223
# cc2_miles          0.020291 -0.008804   -0.013923  -0.068223   1.000000
# cc3_miles         -0.014707  0.035243   -0.007779   0.060555  -0.006166
# Bonus_miles       -0.203012  0.403487    0.031021   0.825200  -0.003969
# Bonus_trans       -0.146915  0.324935    0.050725   0.608943   0.064399
# Flight_miles_12mo -0.031013  0.217551    0.126774   0.037370   0.010598
# Flight_trans_12   -0.052096  0.255700    0.144004   0.041333   0.028284
# Days_since_enroll -0.964988  0.263129    0.017312   0.230849  -0.005807
# Award?            -0.177901  0.178494    0.095256   0.335457   0.005332
#
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
plt.subplot(221)
sns.distplot(data['Qual_miles'])
plt.subplot(222)
sns.distplot(data['cc1_miles'])
plt.subplot(223)
sns.distplot(data['cc2_miles'])
plt.subplot(224)
sns.distplot(data['cc3_miles'])
plt.subplot(224)
sns.distplot(data['Bonus_miles'])
# Out:
# <Axes: xlabel='Bonus_miles', ylabel='Density'>

# %%
data.hist(figsize=(10,8), bins=10)
# Out:
# array([[<Axes: title={'center': 'ID#'}>,
#         <Axes: title={'center': 'Balance'}>,
#         <Axes: title={'center': 'Qual_miles'}>],
#        [<Axes: title={'center': 'cc1_miles'}>,
#         <Axes: title={'center': 'cc2_miles'}>,
#         <Axes: title={'center': 'cc3_miles'}>],
#        [<Axes: title={'center': 'Bonus_miles'}>,
#         <Axes: title={'center': 'Bonus_trans'}>,
#         <Axes: title={'center': 'Flight_miles_12mo'}>],
#        [<Axes: title={'center': 'Flight_trans_12'}>,
#         <Axes: title={'center': 'Days_since_enroll'}>,
#         <Axes: title={'center': 'Award?'}>]], dtype=object)

# %%
sns.barplot(x = 'cc1_miles', y = 'Qual_miles',data = data)
# Out:
# <Axes: xlabel='cc1_miles', ylabel='Qual_miles'>

# %%
sns.barplot(x = 'cc2_miles', y = 'Qual_miles',data = data)
# Out:
# <Axes: xlabel='cc2_miles', ylabel='Qual_miles'>

# %%
sns.barplot(x = 'cc3_miles', y = 'Qual_miles',data = data)
# Out:
# <Axes: xlabel='cc3_miles', ylabel='Qual_miles'>

# %%
sns.barplot(x = 'Award?', y = 'Balance',data = data)
# Out:
# <Axes: xlabel='Award?', ylabel='Balance'>

# %%
sns.pairplot(data)

# %%
sns.scatterplot(x = 'Bonus_trans', y = 'Bonus_miles',data = data)
# Out:
# <Axes: xlabel='Bonus_trans', ylabel='Bonus_miles'>

# %%
sns.scatterplot(x = 'Flight_miles_12mo', y = 'Flight_trans_12',data = data)
# Out:
# <Axes: xlabel='Flight_miles_12mo', ylabel='Flight_trans_12'>

# %%
sns.scatterplot(x = 'Balance', y = 'Bonus_miles',data = data)
# Out:
# <Axes: xlabel='Balance', ylabel='Bonus_miles'>

# %%
array = data.values
array
# Out:
# array([[    1, 28143,     0, ...,     0,  7000,     0],
#        [    2, 19244,     0, ...,     0,  6968,     0],
#        [    3, 41354,     0, ...,     0,  7034,     0],
#        ...,
#        [ 4019, 73597,     0, ...,     0,  1402,     1],
#        [ 4020, 54899,     0, ...,     1,  1401,     0],
#        [ 4021,  3016,     0, ...,     0,  1398,     0]], dtype=int64)

# %% [markdown]
# # K - means Clustering

# %%
X = data[['Balance','Qual_miles','cc1_miles','cc2_miles','cc3_miles','Bonus_miles','Bonus_trans','Flight_miles_12mo','Flight_trans_12','Days_since_enroll','Award?']]
X.head(2)
# Out:
#    Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    28143           0          1          1          1          174
# 1    19244           0          1          1          1          215
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0

# %%
array1 = data.values
array1
# Out:
# array([[    1, 28143,     0, ...,     0,  7000,     0],
#        [    2, 19244,     0, ...,     0,  6968,     0],
#        [    3, 41354,     0, ...,     0,  7034,     0],
#        ...,
#        [ 4019, 73597,     0, ...,     0,  1402,     1],
#        [ 4020, 54899,     0, ...,     1,  1401,     0],
#        [ 4021,  3016,     0, ...,     0,  1398,     0]], dtype=int64)

# %%
cluster = KMeans(n_clusters=6)
cluster.fit(X)

p = cluster.predict(X)
p, len(p)
# Out:
# (array([2, 2, 2, ..., 0, 2, 2]), 3999)

# %%
# creating elbow curve--
wcss =[]
for i in range(1,11):
    kmeans = KMeans(n_clusters = i)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11),wcss)
plt.title("ELBOW CURVE")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
# Out:
# Text(0, 0.5, 'WCSS')

# %%
data['Cluster'] = p
print(data.head())
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?  \
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1
#
#    Cluster
# 0        2
# 1        2
# 2        2
# ...

# %%
# building model--
model = KMeans(n_clusters = 6)
model.fit(X)
# Out:
# KMeans(n_clusters=6)

# %%
c_4 = model.labels_
c_4
# Out:
# array([0, 0, 0, ..., 3, 0, 0])

# %%
md = pd.Series(model.labels_)
data['Clust'] = md
data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
data.iloc[:,1:].groupby(data.Clust).mean()
# Out:
#             Balance   Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# Clust
# 0      2.321407e+04    97.089309   1.468544   1.018038   1.003520
# 1      7.206212e+05   247.391304   3.478261   1.000000   1.130435
# 2      1.771839e+05   253.096639   3.071429   1.008403   1.029412
# 3      8.298586e+04   153.196380   2.685973   1.009050   1.021719
# 4      1.288916e+06  1528.000000   3.000000   1.000000   1.000000
# 5      3.633193e+05   449.094017   3.188034   1.025641   1.000000
#
#         Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# Clust
# 0       7346.464144     8.250770         236.101628         0.741751
# 1      60298.173913    21.608696        1533.478261         5.521739
# 2      34710.457983    17.323529         901.182773         2.445378
# 3      25260.928507    14.862443         578.396380         1.723982
# 4      39098.000000    24.600000        2754.600000        11.400000
# 5      49964.743590    20.111111        1589.487179         4.735043
#
# ...

# %%
sns.scatterplot(x = 'Balance', y = 'Bonus_miles', hue = 'Clust',data = data, palette='summer')
# Out:
# <Axes: xlabel='Balance', ylabel='Bonus_miles'>

# %%
print(data['Clust'].value_counts(normalize=True)*100)
# Out:
# 0    56.839210
# 3    27.631908
# 2    11.902976
# 5     2.925731
# 1     0.575144
# 4     0.125031
# Name: Clust, dtype: float64

# %%
labels = cluster.labels_
silhouette_score(X, labels,metric='euclidean')
# Out:
# 0.5153976406355736

# %%
sc = StandardScaler()
X_scaled = sc.fit_transform(X)
X_scaled
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
cluster = KMeans(n_clusters=6)
cluster.fit(X_scaled)

p1 = cluster.predict(X_scaled)
p1, len(p1)
# Out:
# (array([0, 0, 0, ..., 4, 0, 0]), 3999)

# %%
labels = cluster.labels_
silhouette_score(X_scaled, labels,metric='euclidean')
# Out:
# 0.2753395049183147

# %% [raw]
# From the Airlines Dataset, the Kmeans Clustering model shows greater accuracy score i.e. 51.46% than Standard Scaler accuracy score i.e. 27.53%.
