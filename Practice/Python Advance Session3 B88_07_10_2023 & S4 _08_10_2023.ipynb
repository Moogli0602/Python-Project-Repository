# %%
a = 10
b = 20
print(a+b)
# Out:
# 30

# %%
##### Functins for that  ---
# id()
# len()
# print()
# type()
#### User defined Functions --
#### def function_name(arg1,arg2):
 #       expression and statements

# %%
#### Defning this Functions
def add(a,b):
    c = a+b
    print(c)

# %%
#### Calling this Function
k = add(10,20)
print(k)
# Out:
# 30
# None

# %%
k*2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 k*2
#
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'int'

# %%
def add(a,b):
    c = a+b
    print(c)
    return

# %%
k = add(10,20)
print(k)
# Out:
# 30
# None

# %%
k*2
# Out:
# 60

# %%
import pandas as pd

# %%
def read_data():
    path = "E:/TOPMENTOR/PART1/topmenor/Top Mentor/Datasets/Example.xlsx"
    ex = pd.read_excel(path)
    return ex

# %%
data = read_data()
print(data.head())
# Out:
#    Customer   Age      Sex  Groceries  Choco-bars  Type   Satisfied   Bulk
# 0          1    36    Male        180           3  White           4     3
# 1          2    45    Male        180           4   Milk           3     2
# 2          3    20  Female        220           3  White           2     3
# 3          4    27  Female        180           2  White           4     2
# 4          5    22  Female        220           5   Milk           3     2

# %%
print(data.tail(10))
# Out:
#     Customer   Age      Sex  Groceries  Choco-bars  Type   Satisfied   Bulk
# 40         41    23  Female        220           4   Dark           2     1
# 41         42    24    Male        150           2   Dark           2     1
# 42         43    29    Male        180           4  White           2     4
# 43         44    32    Male        150           4   Dark           2     1
# 44         45    26  Female        250           2  White           4     3
# 45         46    40  Female        250           3   Dark           3     4
# 46         47    37  Female        220           5  White           2     4
# 47         48    23    Male        150           5   Dark           4     3
# 48         49    36    Male        180           4  White           3     3
# 49         50    24    Male        180           2   Dark           4     3

# %%
print(data.info())   #### Information about your data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Customer    50 non-null     int64
#  1   Age         50 non-null     int64
#  2   Sex         50 non-null     object
#  3   Groceries   50 non-null     int64
#  4   Choco-bars  50 non-null     int64
#  5   Type        50 non-null     object
#  6   Satisfied   50 non-null     int64
#  7   Bulk        50 non-null     int64
# dtypes: int64(6), object(2)
# memory usage: 3.3+ KB
# None

# %%
url = 'https://raw.githubusercontent.com/DataScience75/Top_mentor_projects_Datasets/main/titles.csv'

# %%
def read_data_git():
    ex1 = pd.read_csv(url)
    return ex1

# %%
titles = read_data_git()
print(titles.head())
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2         Crucea de piatra  1993
# 3                  Country  2000
# 4               Gaiking II  2011

# %%
dim  = data.shape     ##### Number of rows, number of columns
print("The number of columns - ",dim[1])
print(type(dim))
# Out:
# The number of columns -  8
# <class 'tuple'>

# %%
col = data.columns
print(col)
print(type(col))
# Out:
# Index(['Customer ', 'Age ', 'Sex', 'Groceries', 'Choco-bars', 'Type ',
#        'Satisfied ', 'Bulk'],
#       dtype='object')
# <class 'pandas.core.indexes.base.Index'>

# %%
s[0:5]
# Out:
# Index(['Customer ', 'Age ', 'Sex', 'Groceries', 'Choco-bars'], dtype='object')

# %%
print(type(data['Sex']))
data['Sex']
# Out:
# <class 'pandas.core.series.Series'>
# 0       Male
# 1       Male
# 2     Female
# 3     Female
# 4     Female
# 5       Male
# 6       Male
# 7       Male
# 8     Female
# 9     Female
# 10    Female
# 11      Male
# 12      Male
# 13      Male
# 14    Female
# 15    Female
# 16    Female
# 17      Male
# 18      Male
# 19      Male
# 20    Female
# 21    Female
# 22    Female
# 23      Male
# 24      Male
# 25      Male
# 26    Female
# 27    Female
# 28    Female
# 29      Male
# 30      Male
# 31      Male
# 32    Female
# 33    Female
# 34    Female
# 35      Male
# 36      Male
# 37      Male
# 38    Female
# 39    Female
# 40    Female
# 41      Male
# 42      Male
# 43      Male
# 44    Female
# 45    Female
# 46    Female
# 47      Male
# 48      Male
# 49      Male
# Name: Sex, dtype: object

# %%
data[['Sex','Groceries', 'Choco-bars']]
# Out:
#        Sex  Groceries  Choco-bars
# 0     Male        180           3
# 1     Male        180           4
# 2   Female        220           3
# 3   Female        180           2
# 4   Female        220           5
# 5     Male        150           2
# 6     Male        220           5
# 7     Male        220           2
# 8   Female        250           3
# 9   Female        180           2
# 10  Female        180           2
# 11    Male        150           4
# 12    Male        220           2
# 13    Male        180           5
# 14  Female        200           2
# 15  Female        150           3
# 16  Female        220           4
# 17    Male        220           3
# 18    Male        220           4
# 19    Male        200           4
# 20  Female        220           5
# 21  Female        200           3
# 22  Female        220           3
# 23    Male        250           4
# 24    Male        250           3
# 25    Male        180           3
# ...

# %%
d  = [1,2,3,4]
s = [3,4,5,6]
di = {"d":d,"s":s}
print(di)
d1 = pd.DataFrame(di, index = ['A','B',"C","D"])
d1
# Out:
# {'d': [1, 2, 3, 4], 's': [3, 4, 5, 6]}
#    d  s
# A  1  3
# B  2  4
# C  3  5
# D  4  6

# %%
print(data.columns)
# Out:
# Index(['Customer ', 'Age ', 'Sex', 'Groceries', 'Choco-bars', 'Type ',
#        'Satisfied ', 'Bulk'],
#       dtype='object')

# %%
data1 = data[['Age ','Customer ','Sex','Satisfied ']]
print(data1.head())
# Out:
#    Age   Customer      Sex  Satisfied
# 0    36          1    Male           4
# 1    45          2    Male           3
# 2    20          3  Female           2
# 3    27          4  Female           4
# 4    22          5  Female           3

# %%
print(data['Age '].mean())
# Out:
# 30.4

# %%
print(data['Sex'].value_counts())
# Out:
# Sex
# Male      26
# Female    24
# Name: count, dtype: int64

# %%
print(data['Satisfied '].value_counts())
# Out:
# Satisfied
# 4    15
# 2    15
# 3    13
# 1     7
# Name: count, dtype: int64

# %%
col = data.columns
col
# Out:
# Index(['Customer ', 'Age ', 'Sex', 'Groceries', 'Choco-bars', 'Type ',
#        'Satisfied ', 'Bulk'],
#       dtype='object')

# %%
col[0].strip()
# Out:
# 'Customer'

# %%
updated_col = []

for i in col:
    c = i.strip()
    updated_col.append(c)
    print(c)
# Out:
# Customer
# Age
# Sex
# Groceries
# Choco-bars
# Type
# Satisfied
# Bulk

# %%
print(updated_col)
# Out:
# ['Customer', 'Age', 'Sex', 'Groceries', 'Choco-bars', 'Type', 'Satisfied', 'Bulk']

# %%
##### Chnaging the columns with updated columns
data.columns = updated_col

# %%
data.columns
# Out:
# Index(['Customer', 'Age', 'Sex', 'Groceries', 'Choco-bars', 'Type',
#        'Satisfied', 'Bulk'],
#       dtype='object')

# %%
##### I want to apply the columns in lower case
lower_col = []

for i in data.columns:
    l = i.lower()
    lower_col.append(l)
    print(l)
# Out:
# customer
# age
# sex
# groceries
# choco-bars
# type
# satisfied
# bulk

# %%
data.columns = lower_col

# %%
##### Create a Clone of your data before doing any analysis
cleaned_data = data.copy()
cleaned_data
# Out:
#     customer  age     sex  groceries  choco-bars   type  satisfied  bulk
# 0          1   36    Male        180           3  White          4     3
# 1          2   45    Male        180           4   Milk          3     2
# 2          3   20  Female        220           3  White          2     3
# 3          4   27  Female        180           2  White          4     2
# 4          5   22  Female        220           5   Milk          3     2
# 5          6   39    Male        150           2   Dark          4     2
# 6          7   30    Male        220           5   Dark          2     4
# 7          8   42    Male        220           2   Milk          4     1
# 8          9   20  Female        250           3  White          4     4
# 9         10   40  Female        180           2   Milk          3     1
# 10        11   38  Female        180           2  White          2     3
# 11        12   31    Male        150           4   Dark          2     1
# ...

# %%
male_df = cleaned_data[cleaned_data['sex']== 'Male']
male_df
# Out:
#     customer  age   sex  groceries  choco-bars   type  satisfied  bulk
# 0          1   36  Male        180           3  White          4     3
# 1          2   45  Male        180           4   Milk          3     2
# 5          6   39  Male        150           2   Dark          4     2
# 6          7   30  Male        220           5   Dark          2     4
# 7          8   42  Male        220           2   Milk          4     1
# 11        12   31  Male        150           4   Dark          2     1
# 12        13   19  Male        220           2   Dark          2     3
# 13        14   23  Male        180           5   Dark          1     4
# 17        18   25  Male        220           3   Dark          3     3
# 18        19   34  Male        220           4   Dark          4     1
# 19        20   39  Male        200           4   Dark          4     2
# 23        24   31  Male        250           4   Dark          4     4
# ...

# %% [markdown]
# #### Explorations

# %%
Points that are covered - 
#### What is the average age, max age and min age
#### What type of chocolates the male people like
#### What is the total amount spend in groceries
#### How staisfied are they ?

# %%
print("The average age is  - ", round(male_df['age'].mean(),2))
print("The max age is  - ", male_df['age'].max())
print("The min age is  - ", male_df['age'].min())
print("The total groceries spend is  - ", male_df['groceries'].sum())
print("The type of chocolates liked by male  - ", male_df['type'].value_counts())
print("The male Satisfaction - ", male_df['satisfied'].value_counts())
# Out:
# The average age is  -  32.23
# The max age is  -  45
# The min age is  -  19
# The total groceries spend is  -  5030
# The type of chocolates liked by male  -  type
# Dark     16
# White     5
# Milk      5
# Name: count, dtype: int64
# The male Satisfaction -  satisfied
# 4    9
# 2    7
# 3    5
# 1    5
# Name: count, dtype: int64

# %%
##### Two ways of sorting data
1. sort by index
2. sort by values
# Out:
#     customer  age     sex  groceries  choco-bars   type  satisfied  bulk
# 0          1   36    Male        180           3  White          4     3
# 1          2   45    Male        180           4   Milk          3     2
# 2          3   20  Female        220           3  White          2     3
# 3          4   27  Female        180           2  White          4     2
# 4          5   22  Female        220           5   Milk          3     2
# 5          6   39    Male        150           2   Dark          4     2
# 6          7   30    Male        220           5   Dark          2     4
# 7          8   42    Male        220           2   Milk          4     1
# 8          9   20  Female        250           3  White          4     4
# 9         10   40  Female        180           2   Milk          3     1
# 10        11   38  Female        180           2  White          2     3
# 11        12   31    Male        150           4   Dark          2     1
# ...

# %%
cleaned_data.sort_index(ascending  = False)
# Out:
#     customer  age     sex  groceries  choco-bars   type  satisfied  bulk
# 49        50   24    Male        180           2   Dark          4     3
# 48        49   36    Male        180           4  White          3     3
# 47        48   23    Male        150           5   Dark          4     3
# 46        47   37  Female        220           5  White          2     4
# 45        46   40  Female        250           3   Dark          3     4
# 44        45   26  Female        250           2  White          4     3
# 43        44   32    Male        150           4   Dark          2     1
# 42        43   29    Male        180           4  White          2     4
# 41        42   24    Male        150           2   Dark          2     1
# 40        41   23  Female        220           4   Dark          2     1
# 39        40   44  Female        250           3  White          3     3
# 38        39   20  Female        150           5   Dark          2     4
# ...

# %%
cleaned_data.sort_values(['groceries','satisfied'],ascending  = False)
# Out:
#     customer  age     sex  groceries  choco-bars   type  satisfied  bulk
# 8          9   20  Female        250           3  White          4     4
# 23        24   31    Male        250           4   Dark          4     4
# 29        30   29    Male        250           3  White          4     4
# 44        45   26  Female        250           2  White          4     3
# 39        40   44  Female        250           3  White          3     3
# 45        46   40  Female        250           3   Dark          3     4
# 24        25   32    Male        250           3   Milk          1     3
# 7          8   42    Male        220           2   Milk          4     1
# 18        19   34    Male        220           4   Dark          4     1
# 20        21   20  Female        220           5   Dark          4     1
# 4          5   22  Female        220           5   Milk          3     2
# 17        18   25    Male        220           3   Dark          3     3
# ...

# %%
cleaned_data.set_index('sex',inplace = True)

# %%
cleaned_data.sort_index(ascending  = True)
# Out:
#         customer  age  groceries  choco-bars   type  satisfied  bulk
# sex
# Female        16   24        150           3  White          3     4
# Female        35   18        150           2   Dark          3     1
# Female        29   40        150           4   Dark          2     1
# Female        28   19        200           2   Dark          3     2
# Female        27   22        150           4   Dark          3     3
# Female        23   20        220           3   Dark          2     4
# Female        22   44        200           3   Milk          4     4
# Female        21   20        220           5   Dark          4     1
# Female        39   20        150           5   Dark          2     4
# Female        40   44        250           3  White          3     3
# Female        41   23        220           4   Dark          2     1
# Female        17   28        220           4   Milk          1     3
# Female        34   32        200           5   Milk          1     1
# ...

# %%
cleaned_data.reset_index(inplace = True)

# %%
#### Slicing of dataframe
cleaned_data.head(30)
# Out:
#        sex  customer  age  groceries  choco-bars   type  satisfied  bulk
# 0     Male         1   36        180           3  White          4     3
# 1     Male         2   45        180           4   Milk          3     2
# 2   Female         3   20        220           3  White          2     3
# 3   Female         4   27        180           2  White          4     2
# 4   Female         5   22        220           5   Milk          3     2
# 5     Male         6   39        150           2   Dark          4     2
# 6     Male         7   30        220           5   Dark          2     4
# 7     Male         8   42        220           2   Milk          4     1
# 8   Female         9   20        250           3  White          4     4
# 9   Female        10   40        180           2   Milk          3     1
# 10  Female        11   38        180           2  White          2     3
# 11    Male        12   31        150           4   Dark          2     1
# ...

# %%
####.loc and .iloc
cleaned_data.loc[[28,30,1,5],['age','groceries','sex']]
# Out:
#     age  groceries     sex
# 28   40        150  Female
# 30   40        220    Male
# 1    45        180    Male
# 5    39        150    Male

# %%
cleaned_data.head(2)
# Out:
#     sex  customer  age  groceries  choco-bars   type  satisfied  bulk
# 0  Male         1   36        180           3  White          4     3
# 1  Male         2   45        180           4   Milk          3     2

# %%
cleaned_data.iloc[0:10:3,0:5:2]   ####Inclusive  :Exclusive : Step  #### it works on indexes
# Out:
#       sex  age  choco-bars
# 0    Male   36           3
# 3  Female   27           2
# 6    Male   30           5
# 9  Female   40           2

# %%
cleaned_data.loc[0:10:3,'age']
# Out:
# 0    36
# 3    27
# 6    30
# 9    40
# Name: age, dtype: int64

# %%
###### Grouping of the data - 
cleaned_data.groupby('sex')['groceries'].sum()
# Out:
# sex
# Female    4780
# Male      5030
# Name: groceries, dtype: int64

# %%
cleaned_data.groupby(['sex','type'])['groceries'].sum().reset_index()
# Out:
#       sex   type  groceries
# 0  Female   Dark       1860
# 1  Female   Milk       1020
# 2  Female  White       1900
# 3    Male   Dark       2990
# 4    Male   Milk       1030
# 5    Male  White       1010

# %%
cleaned_data.groupby(['sex','type'])['age'].count().plot(kind = 'barh')
# Out:
# <Axes: ylabel='sex,type'>

# %%
cleaned_data.describe(include = 'all')
# Out:
#          sex  customer        age   groceries  choco-bars  type  satisfied
# count     50  50.00000  50.000000   50.000000    50.00000    50  50.000000  \
# unique     2       NaN        NaN         NaN         NaN     3        NaN
# top     Male       NaN        NaN         NaN         NaN  Dark        NaN
# freq      26       NaN        NaN         NaN         NaN    26        NaN
# mean     NaN  25.50000  30.400000  196.200000     3.42000   NaN   2.720000
# std      NaN  14.57738   8.342172   34.040192     1.12649   NaN   1.050559
# min      NaN   1.00000  18.000000  150.000000     2.00000   NaN   1.000000
# 25%      NaN  13.25000  23.000000  180.000000     2.00000   NaN   2.000000
# 50%      NaN  25.50000  29.500000  200.000000     3.00000   NaN   3.000000
# 75%      NaN  37.75000  37.750000  220.000000     4.00000   NaN   4.000000
# max      NaN  50.00000  45.000000  250.000000     5.00000   NaN   4.000000
#
#              bulk
# count   50.000000
# unique        NaN
# ...

# %%
cleaned_data.to_csv("E:/cleaned_data.csv")   ####
# Out:
#     sex  customer  age  groceries  choco-bars   type  satisfied  bulk
# 0  Male         1   36        180           3  White          4     3
# 1  Male         2   45        180           4   Milk          3     2

# %%
df1 = cleaned_data.pivot_table(columns = ['sex','type'],index='customer', values = 'groceries',aggfunc= sum)
#df1 = df1.reset_index()
df1
# Out:
# sex      Female                 Male
# type       Dark   Milk  White   Dark   Milk  White
# customer
# 1           NaN    NaN    NaN    NaN    NaN  180.0
# 2           NaN    NaN    NaN    NaN  180.0    NaN
# 3           NaN    NaN  220.0    NaN    NaN    NaN
# 4           NaN    NaN  180.0    NaN    NaN    NaN
# 5           NaN  220.0    NaN    NaN    NaN    NaN
# 6           NaN    NaN    NaN  150.0    NaN    NaN
# 7           NaN    NaN    NaN  220.0    NaN    NaN
# 8           NaN    NaN    NaN    NaN  220.0    NaN
# 9           NaN    NaN  250.0    NaN    NaN    NaN
# 10          NaN  180.0    NaN    NaN    NaN    NaN
# 11          NaN    NaN  180.0    NaN    NaN    NaN
# 12          NaN    NaN    NaN  150.0    NaN    NaN
# 13          NaN    NaN    NaN  220.0    NaN    NaN
# 14          NaN    NaN    NaN  180.0    NaN    NaN
# 15          NaN    NaN  200.0    NaN    NaN    NaN
# 16          NaN    NaN  150.0    NaN    NaN    NaN
# ...

# %%
df1 = df1.reset_index()

# %%
df1
# Out:
# sex  customer Female                 Male
# type            Dark   Milk  White   Dark   Milk  White
# 0           1    NaN    NaN    NaN    NaN    NaN  180.0
# 1           2    NaN    NaN    NaN    NaN  180.0    NaN
# 2           3    NaN    NaN  220.0    NaN    NaN    NaN
# 3           4    NaN    NaN  180.0    NaN    NaN    NaN
# 4           5    NaN  220.0    NaN    NaN    NaN    NaN
# 5           6    NaN    NaN    NaN  150.0    NaN    NaN
# 6           7    NaN    NaN    NaN  220.0    NaN    NaN
# 7           8    NaN    NaN    NaN    NaN  220.0    NaN
# 8           9    NaN    NaN  250.0    NaN    NaN    NaN
# 9          10    NaN  180.0    NaN    NaN    NaN    NaN
# 10         11    NaN    NaN  180.0    NaN    NaN    NaN
# 11         12    NaN    NaN    NaN  150.0    NaN    NaN
# 12         13    NaN    NaN    NaN  220.0    NaN    NaN
# 13         14    NaN    NaN    NaN  180.0    NaN    NaN
# 14         15    NaN    NaN  200.0    NaN    NaN    NaN
# ...

# %%
##### Create New Columns
titles['year_dup'] = titles['year']

# %%
titles
# Out:
#                                        title  year  year_dup
# 0                             The Rising Son  1990      1990
# 1                    The Thousand Plane Raid  1969      1969
# 2                           Crucea de piatra  1993      1993
# 3                                    Country  2000      2000
# 4                                 Gaiking II  2011      2011
# ...                                      ...   ...       ...
# 230616                 Nobody Waved Good-bye  1964      1964
# 230617                                 E yue  2005      2005
# 230618                          Lakota Girls  2015      2015
# 230619                        Kroniki domowe  1997      1997
# 230620  Death in the Valley of Good and Evil  2018      2018
#
# [230621 rows x 3 columns]

# %%
###### To drop the columns    #### axis = 1, stands for columns, axis = 0 stands for rows
titles.drop('year_dup',axis = 1,inplace = True)

# %%
titles.dtypes   ##### It show the data types of the columns
# Out:
# title    object
# year      int64
# dtype: object

# %%
titles['Decade'] = titles.year //10*10
titles
# Out:
#                                        title  year  Decade
# 0                             The Rising Son  1990    1990
# 1                    The Thousand Plane Raid  1969    1960
# 2                           Crucea de piatra  1993    1990
# 3                                    Country  2000    2000
# 4                                 Gaiking II  2011    2010
# ...                                      ...   ...     ...
# 230616                 Nobody Waved Good-bye  1964    1960
# 230617                                 E yue  2005    2000
# 230618                          Lakota Girls  2015    2010
# 230619                        Kroniki domowe  1997    1990
# 230620  Death in the Valley of Good and Evil  2018    2010
#
# [230621 rows x 3 columns]

# %%
titles['Century'] = titles.year //100*100
titles
# Out:
#                                        title  year  Decade  Century
# 0                             The Rising Son  1990    1990     1900
# 1                    The Thousand Plane Raid  1969    1960     1900
# 2                           Crucea de piatra  1993    1990     1900
# 3                                    Country  2000    2000     2000
# 4                                 Gaiking II  2011    2010     2000
# ...                                      ...   ...     ...      ...
# 230616                 Nobody Waved Good-bye  1964    1960     1900
# 230617                                 E yue  2005    2000     2000
# 230618                          Lakota Girls  2015    2010     2000
# 230619                        Kroniki domowe  1997    1990     1900
# 230620  Death in the Valley of Good and Evil  2018    2010     2000
#
# [230621 rows x 4 columns]
